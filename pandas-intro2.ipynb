# %%
import pandas as pd

# %% [markdown]
# creating data from data
# #column from series

# %%
carsales = pd.read_csv('car-sales.csv')
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
seatcol = pd.Series([5,3,4,5,5,5,4,4,5,5])

# %%
carsales['seats'] = seatcol
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00      5
# 1   Honda    Red          87899      4   $5,000.00      3
# 2  Toyota   Blue          32549      3   $7,000.00      4
# 3     BMW  Black          11179      5  $22,000.00      5
# 4  Nissan  White         213095      4   $3,500.00      5
# 5  Toyota  Green          99213      4   $4,500.00      5
# 6   Honda   Blue          45698      4   $7,500.00      4
# 7   Honda   Blue          54738      4   $7,000.00      4
# 8  Toyota  White          60000      4   $6,250.00      5
# 9  Nissan  White          31600      4   $9,700.00      5

# %%
fuel = [9,8,8,7,7,7,10,11,9,8]
carsales['fuel (100KM)'] = fuel
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)
# 0  Toyota  White         150043      4   $4,000.00      5             9
# 1   Honda    Red          87899      4   $5,000.00      3             8
# 2  Toyota   Blue          32549      3   $7,000.00      4             8
# 3     BMW  Black          11179      5  $22,000.00      5             7
# 4  Nissan  White         213095      4   $3,500.00      5             7
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 6   Honda   Blue          45698      4   $7,500.00      4            10
# 7   Honda   Blue          54738      4   $7,000.00      4            11
# 8  Toyota  White          60000      4   $6,250.00      5             9
# 9  Nissan  White          31600      4   $9,700.00      5             8

# %%
carsales['total fuel (L)'] = carsales['Odometer (KM)']/100 * carsales['fuel (100KM)']
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)  \
# 0  Toyota  White         150043      4   $4,000.00      5             9
# 1   Honda    Red          87899      4   $5,000.00      3             8
# 2  Toyota   Blue          32549      3   $7,000.00      4             8
# 3     BMW  Black          11179      5  $22,000.00      5             7
# 4  Nissan  White         213095      4   $3,500.00      5             7
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 6   Honda   Blue          45698      4   $7,500.00      4            10
# 7   Honda   Blue          54738      4   $7,000.00      4            11
# 8  Toyota  White          60000      4   $6,250.00      5             9
# 9  Nissan  White          31600      4   $9,700.00      5             8
#
#    total fuel (L)
# 0        13503.87
# 1         7031.92
# 2         2603.92
# 3          782.53
# 4        14916.65
# 5         6944.91
# 6         4569.80
# 7         6021.18
# ...

# %%
carsales['wheels'] = 4
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)  \
# 0  Toyota  White         150043      4   $4,000.00      5             9
# 1   Honda    Red          87899      4   $5,000.00      3             8
# 2  Toyota   Blue          32549      3   $7,000.00      4             8
# 3     BMW  Black          11179      5  $22,000.00      5             7
# 4  Nissan  White         213095      4   $3,500.00      5             7
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 6   Honda   Blue          45698      4   $7,500.00      4            10
# 7   Honda   Blue          54738      4   $7,000.00      4            11
# 8  Toyota  White          60000      4   $6,250.00      5             9
# 9  Nissan  White          31600      4   $9,700.00      5             8
#
#    total fuel (L)  wheels
# 0        13503.87       4
# 1         7031.92       4
# 2         2603.92       4
# 3          782.53       4
# 4        14916.65       4
# ...

# %%
carsales['safety'] = True
carsales.dtypes
# Out:
# Make               object
# Colour             object
# Odometer (KM)       int64
# Doors               int64
# Price              object
# seats               int64
# fuel (100KM)        int64
# total fuel        float64
# total fuel (L)    float64
# wheels              int64
# safety               bool
# dtype: object

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)  \
# 0  Toyota  White         150043      4   $4,000.00      5             9
# 1   Honda    Red          87899      4   $5,000.00      3             8
# 2  Toyota   Blue          32549      3   $7,000.00      4             8
# 3     BMW  Black          11179      5  $22,000.00      5             7
# 4  Nissan  White         213095      4   $3,500.00      5             7
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 6   Honda   Blue          45698      4   $7,500.00      4            10
# 7   Honda   Blue          54738      4   $7,000.00      4            11
# 8  Toyota  White          60000      4   $6,250.00      5             9
# 9  Nissan  White          31600      4   $9,700.00      5             8
#
#    total fuel (L)  wheels
# 0        13503.87       4
# 1         7031.92       4
# 2         2603.92       4
# 3          782.53       4
# 4        14916.65       4
# ...

# %%
carsales.drop('safety', axis=1, inplace = True)
carsales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 carsales.drop('safety', axis=1, inplace = True)
#       2 carsales
#
# File ~\Desktop\sample1\env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\Desktop\sample1\env\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
carsalesshuffle = carsales.sample(frac = 1)
carsalesshuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)  \
# 6   Honda   Blue          45698      4   $7,500.00      4            10
# 9  Nissan  White          31600      4   $9,700.00      5             8
# 3     BMW  Black          11179      5  $22,000.00      5             7
# 7   Honda   Blue          54738      4   $7,000.00      4            11
# 1   Honda    Red          87899      4   $5,000.00      3             8
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 0  Toyota  White         150043      4   $4,000.00      5             9
# 8  Toyota  White          60000      4   $6,250.00      5             9
# 2  Toyota   Blue          32549      3   $7,000.00      4             8
# 4  Nissan  White         213095      4   $3,500.00      5             7
#
#    total fuel (L)  wheels
# 6         4569.80       4
# 9         2528.00       4
# 3          782.53       4
# 7         6021.18       4
# 1         7031.92       4
# ...

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#only working on 20% of the data
carsalesshuffle.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  seats  fuel (100KM)  \
# 8  Toyota  White          60000      4  $6,250.00      5             9
# 5  Toyota  Green          99213      4  $4,500.00      5             7
#
#    total fuel (L)  wheels
# 8         5400.00       4
# 5         6944.91       4

# %%
carsalesshuffle.reset_index(drop = True, inplace = True)
carsalesshuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  fuel (100KM)  \
# 0   Honda   Blue          45698      4   $7,500.00      4            10
# 1  Nissan  White          31600      4   $9,700.00      5             8
# 2     BMW  Black          11179      5  $22,000.00      5             7
# 3   Honda   Blue          54738      4   $7,000.00      4            11
# 4   Honda    Red          87899      4   $5,000.00      3             8
# 5  Toyota  Green          99213      4   $4,500.00      5             7
# 6  Toyota  White         150043      4   $4,000.00      5             9
# 7  Toyota  White          60000      4   $6,250.00      5             9
# 8  Toyota   Blue          32549      3   $7,000.00      4             8
# 9  Nissan  White         213095      4   $3,500.00      5             7
#
#    total fuel (L)  wheels
# 0         4569.80       4
# 1         2528.00       4
# 2          782.53       4
# 3         6021.18       4
# 4         7031.92       4
# ...

# %%
carsales["Odometer (KM)"] = carsales["Odometer (KM)"].apply(lambda x : x/1.6)

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00
